# %%
from sklearn.datasets import fetch_california_housing

# %%
housing = fetch_california_housing()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(housing.data,housing.target,random_state=42)

# %%
import tensorflow as tf
import keras

# %%
tf.random.set_seed(42)

# %%
normalization_layer = Normalization()
hidden_layer1 = tf.keras.layers.Dense(30, activation='relu')
hidden_layer2 = tf.keras.layers.Dense(30, activation='relu')
concat_layer = tf.keras.layers.Concatenate()
output_layer = tf.keras.layers.Dense(1)

# %%
input_ = tf.keras.layers.Input(shape=x_train.shape[1:])
normalized = normalization_layer(input_)
hidden1 = hidden_layer1(normalized)
hidden2 = hidden_layer2(hidden1)
concat = concat_layer([normalized, hidden2])
output = output_layer(concat)
model = tf.keras.Model(inputs=[input_], outputs=[output])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2             │ (None, 8)              │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normalization_2           │ (None, 8)              │             17 │ input_layer_2[0][0]    │
# │ (Normalization)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# ...

# %%
normalization_layer.adapt(x_train)
history = model.fit(x_train, y_train, epochs=20, validation_split=0.2)
# Out:
# Epoch 1/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5128 - loss: 0.2630 - val_RootMeanSquaredError: 0.5299 - val_loss: 0.2808
# Epoch 2/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5130 - loss: 0.2632 - val_RootMeanSquaredError: 0.5364 - val_loss: 0.2877
# Epoch 3/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5145 - loss: 0.2648 - val_RootMeanSquaredError: 0.5322 - val_loss: 0.2833
# Epoch 4/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5108 - loss: 0.2610 - val_RootMeanSquaredError: 0.5351 - val_loss: 0.2863
# Epoch 5/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5105 - loss: 0.2607 - val_RootMeanSquaredError: 0.5319 - val_loss: 0.2829
# Epoch 6/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5083 - loss: 0.2585 - val_RootMeanSquaredError: 0.5320 - val_loss: 0.2830
# Epoch 7/20
# ...

# %%
mse_test=  model.evaluate(x_test,y_test)
# Out:
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - RootMeanSquaredError: 0.5236 - loss: 0.2745

# %%
import pandas as pd
x_new = x_test[:3]
y_pred = model.predict(x_new)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
pd.DataFrame(y_pred)
# Out:
#           0
# 0  0.343457
# 1  0.809422
# 2  4.501656

# %%
pd.DataFrame(y_test[:3])
# Out:
#          0
# 0  0.47700
# 1  0.45800
# 2  5.00001

# %%
input_wide = tf.keras.layers.Input(shape=[5])
input_deep = tf.keras.layers.Input(shape=[6])

norm_layer_deep = tf.keras.layers.Normalization()
norm_layer_wide = tf.keras.layers.Normalization()
# Apply normalization layer to the input tensors
norm_wide = normalization_layer(input_wide)
norm_deep = normalization_layer(input_deep)

# Define the rest of the model
hidden1 = tf.keras.layers.Dense(30, activation='relu')(norm_deep)
hidden2 = tf.keras.layers.Dense(30, activation='relu')(hidden1)

concat = concat_layer([norm_wide, hidden2])  # Use norm_wide instead of norm_wide_layers
output = tf.keras.layers.Dense(1)(concat)


model = tf.keras.Model(inputs=[input_wide, input_deep], outputs=[output])
model.summary()
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_24            │ (None, 6)              │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normalization_10          │ (None, 6)              │             13 │ input_layer_24[0][0]   │
# │ (Normalization)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# ...

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(loss="mse", optimizer=optimizer,metrics=["mae"])

# %%
x_train_wide = x_train[:, :5]
x_train_deep = x_train[:, 2:]
x_valid_wide = x_test[:, :5]
x_valid_deep = x_test[:, 2:]

# %%
norm_layer_wide.adapt(x_train_wide)
norm_layer_deep.adapt(x_train_deep)
model.fit((x_train_wide, x_train_deep), y_train, epochs=20, validation_split=0.2)
# Out:
# Epoch 1/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 2.6473 - mae: 1.1951 - val_loss: 0.6178 - val_mae: 0.5671
# Epoch 2/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.5452 - mae: 0.5382 - val_loss: 0.5146 - val_mae: 0.5116
# Epoch 3/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4546 - mae: 0.4902 - val_loss: 0.4644 - val_mae: 0.4864
# Epoch 4/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4127 - mae: 0.4653 - val_loss: 0.4324 - val_mae: 0.4710
# Epoch 5/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3877 - mae: 0.4500 - val_loss: 0.4134 - val_mae: 0.4617
# Epoch 6/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3736 - mae: 0.4409 - val_loss: 0.3988 - val_mae: 0.4540
# Epoch 7/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3634 - mae: 0.4341 - val_loss: 0.3897 - val_mae: 0.4485
# Epoch 8/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3552 - mae: 0.4286 - val_loss: 0.3829 - val_mae: 0.4442
# Epoch 9/20
# ...

# %%
mse_test = model.evaluate((x_valid_wide, x_valid_deep), y_test)
# Out:
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3304 - mae: 0.4064

# %%
x_new_wide , x_new_deep = x_valid_wide[:3], x_valid_deep[:3]
y_pred = model.predict((x_new_wide, x_new_deep))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step

# %%
pd.DataFrame(y_pred)
# Out:
#           0
# 0  0.544850
# 1  1.411146
# 2  3.934243

# %%
y_test[:3]
# Out:
# array([0.477  , 0.458  , 5.00001])

# %%
import tensorflow as tf

input_wide = tf.keras.layers.Input(shape=[5])
input_deep = tf.keras.layers.Input(shape=[6])

# Initialize separate Normalization layers
norm_layer_deep = tf.keras.layers.Normalization()
norm_layer_wide = tf.keras.layers.Normalization()

# Apply normalization layer to the input tensors
norm_wide = norm_layer_wide(input_wide)
norm_deep = norm_layer_deep(input_deep)

# Define the rest of the model
hidden1 = tf.keras.layers.Dense(30, activation='relu')(norm_deep)
hidden2 = tf.keras.layers.Dense(30, activation='relu')(hidden1)

# Apply a Dense layer to norm_wide to match hidden2's shape
norm_wide_adjusted = tf.keras.layers.Dense(30, activation='relu')(norm_wide)

# Concatenate the adjusted norm_wide with hidden2
concat = tf.keras.layers.concatenate([norm_wide_adjusted, hidden2])

output = tf.keras.layers.Dense(1)(concat)
aux_output = tf.keras.layers.Dense(1)(hidden2) # aux_output eklendi

model = tf.keras.Model(inputs=[input_wide, input_deep], outputs=[output, aux_output]) # Çıktılar güncellendi

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
# Provide a list of metrics for each output
# Each sub-list corresponds to the metrics for a specific output
model.compile(loss="mse", optimizer=optimizer, metrics=[['mae'], ['mae']]) # Changed metrics to [['mae'], ['mae']]
norm_layer_wide.adapt(x_train_wide)
norm_layer_deep.adapt(x_train_deep)
model.fit((x_train_wide, x_train_deep), (y_train,y_train), epochs=20, validation_split=0.2)
# Out:
# Epoch 1/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - dense_48_loss: 1.7414 - dense_48_mae: 0.9576 - dense_49_loss: 1.9105 - dense_49_mae: 1.0118 - loss: 3.6519 - val_dense_48_loss: 0.5406 - val_dense_48_mae: 0.5257 - val_dense_49_loss: 0.7275 - val_dense_49_mae: 0.6371 - val_loss: 1.2677
# Epoch 2/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - dense_48_loss: 0.4798 - dense_48_mae: 0.5010 - dense_49_loss: 0.6571 - dense_49_mae: 0.6050 - loss: 1.1369 - val_dense_48_loss: 0.4553 - val_dense_48_mae: 0.4771 - val_dense_49_loss: 0.6163 - val_dense_49_mae: 0.5714 - val_loss: 1.0715
# Epoch 3/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - dense_48_loss: 0.4134 - dense_48_mae: 0.4623 - dense_49_loss: 0.5727 - dense_49_mae: 0.5547 - loss: 0.9862 - val_dense_48_loss: 0.4308 - val_dense_48_mae: 0.4631 - val_dense_49_loss: 0.5755 - val_dense_49_mae: 0.5493 - val_loss: 1.0063
# Epoch 4/20
# ...

# %%
eval_results = model.evaluate((x_valid_wide, x_valid_deep), (y_test,y_test))
# Out:
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - dense_48_loss: 0.3089 - dense_48_mae: 0.3879 - dense_49_loss: 0.3806 - dense_49_mae: 0.4420 - loss: 0.6894

# %%
eval_results = model.evaluate((x_valid_wide, x_valid_deep), (y_test, y_test))

# Unpack the eval_results according to the metrics defined during model compilation
total_loss, main_loss, aux_loss, main_mae, aux_mae = eval_results
# Out:
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - dense_48_loss: 0.3089 - dense_48_mae: 0.3879 - dense_49_loss: 0.3806 - dense_49_mae: 0.4420 - loss: 0.6894

# %%
y_main_pred, y_aux_pred = model.predict((x_new_wide, x_new_deep))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step

# %%
y_main_pred
# Out:
# array([[0.5881971],
#        [1.0379606],
#        [4.072566 ]], dtype=float32)
