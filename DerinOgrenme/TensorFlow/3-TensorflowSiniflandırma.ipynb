# %%
import pandas as pd
import numpy as np
import keras
import tensorflow as tf

# %%
dataFrame = pd.read_excel("maliciousornot.xlsx")

# %%
dataFrame
# Out:
#      Type  URL_LENGTH  NUMBER_SPECIAL_CHARACTERS  TCP_CONVERSATION_EXCHANGE  \
# 0       1   23.303047                  13.445560                 159.066933
# 1       1   26.645007                  23.018073                 172.149800
# 2       1   25.505113                  27.525833                 168.393333
# 3       1   14.792707                  26.398893                 100.491960
# 4       1   26.282313                  18.575080                 174.999533
# ..    ...         ...                        ...                        ...
# 543     1   27.927387                  29.002513                 183.937333
# 544     1   26.075060                  36.593167                 169.947733
# 545     1   21.502533                  36.372960                 140.284600
# 546     1   26.683867                  37.992127                 181.476200
# 547     0   10.051787                  31.787480                  62.072373
#
# ...

# %%
y = dataFrame["Type"].values

# %%
x = dataFrame.drop("Type",axis=1).values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.33,random_state=15)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from keras.models import Sequential
from keras.layers import Dense , Activation , Dropout
from keras.callbacks import EarlyStopping

# %%
model = Sequential()
model.add(Dense(units=30,activation="relu"))
model.add(Dense(units=15,activation="relu"))
model.add(Dense(units=15,activation="relu"))
model.add(Dense(units=1,activation="sigmoid"))

model.compile(loss="binary_crossentropy",optimizer="adam")

# %%
model.fit(x_train,y_train,epochs=700,validation_data=(x_test,y_test),verbose=1)
# Out:
# Epoch 1/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6767 - val_loss: 0.6761
# Epoch 2/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6610 - val_loss: 0.6625
# Epoch 3/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6396 - val_loss: 0.6419
# Epoch 4/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6136 - val_loss: 0.6165
# Epoch 5/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5885 - val_loss: 0.5823
# Epoch 6/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5224 - val_loss: 0.5393
# Epoch 7/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4769 - val_loss: 0.4899
# Epoch 8/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4105 - val_loss: 0.4411
# Epoch 9/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3663 - val_loss: 0.3977
# Epoch 10/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3016 - val_loss: 0.3764
# Epoch 11/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2921 - val_loss: 0.3386
# Epoch 12/700
# ...

# %%
from sklearn.preprocessing import StandardScaler

# Öncelikle özellik sütunlarını ayırıyoruz, hedef sütunu dışarıda bırakıyoruz
features = dataFrame.drop(columns=['Type'])

# Seçilen satırı (örn. 34. satır) iki boyutlu hale getirelim ve ölçekleyelim
single_row_scaled = scaler.fit_transform(features.loc[[34]])

# %%
# Modelle tahmin yapma
tahmin = model.predict(single_row_scaled)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
tahmin
# Out:
# array([[2.708521e-15]], dtype=float32)

# %%
model.history.history
# Out:
# {}

# %%
modelKaybi = pd.DataFrame(model.history.history)

# %%
earlystop = EarlyStopping(monitor="vall_loss",mode="min",verbose=1,patience=25)

# %%
model.fit(x=x_train,y=y_train,epochs=700,validation_data=(x_test,y_test),verbose=1,callbacks=[earlystop])
# Out:
# Epoch 1/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6907 - val_loss: 0.6861
# Epoch 2/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6738 - val_loss: 0.6752
# Epoch 3/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6549 - val_loss: 0.6654
# Epoch 4/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6369 - val_loss: 0.6543
# Epoch 5/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5988 - val_loss: 0.6390
# Epoch 6/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5555 - val_loss: 0.6176
# Epoch 7/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5345 - val_loss: 0.5844
# Epoch 8/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5009 - val_loss: 0.5628
# Epoch 9/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4607 - val_loss: 0.5297
# Epoch 10/700
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4240 - val_loss: 0.4933
# Epoch 11/700
# ...
